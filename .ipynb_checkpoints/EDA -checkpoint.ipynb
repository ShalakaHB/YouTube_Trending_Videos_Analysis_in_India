# %% [markdown]
# ##  YouTube Data Collection and Analysis

# %% [markdown]
# #### Here's a step-by-step guide to performing Exploratory Data Analysis (EDA) for your YouTube Trending Videos dataset:

# %% [markdown]
# ### 1. Loading the dataset and necessary libraries

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'trending_videos_IN.csv'  # Update the path
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head()
# Out:
#       video_id                                              title  \
# 0  HNYA6bqL6bU  Devara Release Trailer (Telugu) | NTR | Saif A...
# 1  1hma1Vax9aA  #ECL | Qualifier 2 | Haryanvi Hunters vs Mumba...
# 2  pE1qTi_Lt8E  Vettaiyan - Prevue | Rajinikanth | Amitabh Bac...
# 3  364HfM-UT18                    JAM | Part 2 | Karikku | Comedy
# 4  qtKJIDcWUZg    Stress Free day out with Hussain 💛😎 Manimegalai
#
#                                          description          published_at  \
# 0  Here’s Devara Part - 1 Telugu Release Trailer ...  2024-09-22T08:37:14Z
# 1  Get ready for the Qualifier 2 of the Entertain...  2024-09-21T18:00:20Z
# 2  Vettaiyan - Prevue | Rajinikanth | Amitabh Bac...  2024-09-20T13:39:03Z
# 3  https://forms.gle/Nh4WRJqToFW8FRcYA\n\nഅക്കൗണ്...  2024-09-20T12:29:58Z
# 4  Subscribe : @HussainManimegalai\n\nFor Adverti...  2024-09-21T12:43:57Z
#
#                  channel_id                      channel_title  category_id  \
# ...

# %% [markdown]
# ### 2. Understanding the Data Structure

# %%
# Basic information about the dataset
df.info()

# Summary statistics for numerical columns
df.describe()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        149 non-null    object
#  1   title           149 non-null    object
#  2   description     147 non-null    object
#  3   published_at    149 non-null    object
#  4   channel_id      149 non-null    object
#  5   channel_title   149 non-null    object
#  6   category_id     149 non-null    int64
#  7   tags            149 non-null    object
#  8   duration        149 non-null    object
#  9   definition      149 non-null    object
#  10  caption         149 non-null    bool
#  11  view_count      149 non-null    int64
#  12  like_count      149 non-null    int64
#  13  dislike_count   149 non-null    int64
#  14  favorite_count  149 non-null    int64
#  15  comment_count   149 non-null    int64
# dtypes: bool(1), int64(6), object(9)
# memory usage: 17.7+ KB
# ...

# %% [markdown]
# ### 3. Handling Missing Data

# %%
# Fill missing values in the 'description' column with a placeholder string
df['description'].fillna('No Description', inplace=True)

# %% [markdown]
# ### 4. Analyzing Categorical Features

# %%
# Check the column names in the dataset
print(df_cleaned.columns)
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_id',
#        'channel_title', 'category_id', 'tags', 'duration', 'definition',
#        'caption', 'view_count', 'like_count', 'dislike_count',
#        'favorite_count', 'comment_count'],
#       dtype='object')

# %% [markdown]
# ##### Plotting Distribution of Video Categories

# %%
# Plotting distribution of video categories (category_id)
plt.figure(figsize=(10, 6))
sns.countplot(y='category_id', data=df_cleaned, order=df_cleaned['category_id'].value_counts().index)
plt.title('Distribution of Video Categories (by Category ID)')
plt.xlabel('Count')
plt.ylabel('Category ID')
plt.show()

# %% [markdown]
# ##### mapping for category_id to category names:

# %%
# Assuming you have a category_id to category_name mapping
category_mapping = {
    1: 'Film & Animation',
    2: 'Autos & Vehicles',
    # Add other category mappings
}

# Create a new column 'category_name'
df_cleaned['category_name'] = df_cleaned['category_id'].map(category_mapping)

# Plotting distribution of video categories (category_name)
plt.figure(figsize=(10, 6))
sns.countplot(y='category_name', data=df_cleaned, order=df_cleaned['category_name'].value_counts().index)
plt.title('Distribution of Video Categories')
plt.xlabel('Count')
plt.ylabel('Category Name')
plt.show()
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_24504\153834200.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['category_name'] = df_cleaned['category_id'].map(category_mapping)

# %% [markdown]
# #####  Plotting Top Trending Channels

# %%
# Checking top trending channels
top_channels = df_cleaned['channel_title'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_channels.values, y=top_channels.index)
plt.title('Top 10 Trending Channels')
plt.xlabel('Number of Videos')
plt.ylabel('Channel Title')
plt.show()

# %% [markdown]
# ### 5. Analyzing Numeric Features

# %%
# Visualizing the distribution of views, likes, dislikes, and comment count
fig, ax = plt.subplots(2, 2, figsize=(14, 10))

# Distribution of Views
sns.histplot(df_cleaned['view_count'], bins=30, ax=ax[0, 0])
ax[0, 0].set_title('Distribution of Views')

# Distribution of Likes
sns.histplot(df_cleaned['like_count'], bins=30, ax=ax[0, 1])
ax[0, 1].set_title('Distribution of Likes')

# Distribution of Dislikes
sns.histplot(df_cleaned['dislike_count'], bins=30, ax=ax[1, 0])
ax[1, 0].set_title('Distribution of Dislikes')

# Distribution of Comment Count
sns.histplot(df_cleaned['comment_count'], bins=30, ax=ax[1, 1])
ax[1, 1].set_title('Distribution of Comment Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Correlation Analysis

# %%
# correlation matrix
correlation_matrix = df[['view_count', 'like_count', 'comment_count']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, linecolor='black')
plt.title('Correlation Matrix of Engagement Metrics')
plt.show()

# %% [markdown]
# ### 7. Identifying Popular Trends

# %%
# Top 10 trending videos by view count
top_videos = df_cleaned.nlargest(10, 'view_count')[['title', 'channel_title', 'view_count', 'like_count', 'dislike_count', 'comment_count']]
print(top_videos)

# Analyzing the relationship between views and likes
sns.scatterplot(x='view_count', y='like_count', data=df_cleaned)
plt.title('Relationship between Views and Likes')
plt.show()
# Out:
#                                                  title     channel_title  \
# 87   Kabhi Main Kabhi Tum Episode 21 | Fahad Mustaf...    ARY Digital HD
# 63   Jaan Nisar Ep 54 - [Eng Sub] - Digitally Prese...       HAR PAL GEO
# 0    Devara Release Trailer (Telugu) | NTR | Saif A...          NTR Arts
# 7    Jaan Nisar Ep 55 - [Eng Sub] - Digitally Prese...       HAR PAL GEO
# 102  INDIA'S GOT LATENT | EP 06 ft. @VipulGoyal @Jo...       Samay Raina
# 11   Kaffara Episode 58 - [Eng Sub] - Ali Ansari - ...       HAR PAL GEO
# 10                          skibidi toilet 77 (part 3)      DaFuq!?Boom!
# 32   Jafaa - Ep 18 - [CC] 20th Sep 2024 - Sponsored...            HUM TV
# 42   Full Video: Whistle Podu | The Greatest Of All...    T-Series Tamil
# 116          iPhone 16/16 Pro Unboxing: End of an Era!  Marques Brownlee
#
#      view_count  like_count  dislike_count  comment_count
# 87     21037925      352885              0          13377
# ...

# %% [markdown]
# ### 8. Sentiment Analysis

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#     --------------------------------------- 10.2/626.3 kB ? eta -:--:--
#    --- ----------------------------------- 61.4/626.3 kB 825.8 kB/s eta 0:00:01
#    ------------ --------------------------- 194.6/626.3 kB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 471.0/626.3 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
from textblob import TextBlob

# Function to calculate sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Apply the function to the video titles or descriptions
df_cleaned['sentiment'] = df_cleaned['title'].apply(get_sentiment)

# Distribution of sentiment scores
plt.figure(figsize=(10, 6))
sns.histplot(df_cleaned['sentiment'], bins=20)
plt.title('Distribution of Sentiment Scores')
plt.show()
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_24504\2015032166.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['sentiment'] = df_cleaned['title'].apply(get_sentiment)

# %% [markdown]
# ### 9. Time-Based Analysis

# %%
# Convert 'published_at' to datetime format
df_cleaned['published_at'] = pd.to_datetime(df_cleaned['published_at'])

# Plot number of trending videos over time
df_cleaned['publish_date'] = df_cleaned['published_at'].dt.date

# Visualizing the number of trending videos over time
plt.figure(figsize=(10, 6))
df_cleaned['publish_date'].value_counts().sort_index().plot()
plt.title('Number of Trending Videos Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Trending Videos')
plt.show()
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_24504\2506671410.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['published_at'] = pd.to_datetime(df_cleaned['published_at'])
# C:\Users\barad\AppData\Local\Temp\ipykernel_24504\2506671410.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['publish_date'] = df_cleaned['published_at'].dt.date
